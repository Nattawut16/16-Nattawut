# %% [markdown]
# <a href="https://colab.research.google.com/github/Nattawut16/16-Nattawut/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names1 = input("ชื่อกิจกรรมที่1:")
hour1 = int(input("ชั่วโมง:"))

names2 = input("ชื่อกิจกรรมที่2:")
hour2 = int(input("ชั่วโมง:"))

sleep = int(input("ชั่วโมงที่ต้องการนอน:"))

total = hour1 + hour2
bedtime = 24 - sleep

print("ตารางกิจกรรม")
print(names1, "=", hour1, "ชม.")
print(names2, "=", hour2, "ชม.")
print("ควรนอนเวลา:", bedtime , "นาฬิกา")
