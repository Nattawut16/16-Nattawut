# %% [markdown]
# <a href="https://colab.research.google.com/github/Nattawut16/16-Nattawut/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
db = float(input("กรอกค่าเดซิเบล"))
if db > 85:
    print("อันตรายต่อหู😖")
else :
    print("ไม่อันตรายต่อหู😁")
# Out:
# กรอกค่าเดซิเบล22
# ไม่อันตรายต่อหู

# %%
names1 = input("ชื่อกิจกรรมที่1:")
hour1 = int(input("ชั่วโมง:"))

names2 = input("ชื่อกิจกรรมที่2:")
hour2 = int(input("ชั่วโมง:"))

sleep = int(input("ชั่วโมงที่ต้องการนอน:"))

total = hour1 + hour2
bedtime = 24 - sleep

print("ตารางกิจกรรม")
print(names1, "=", hour1, "ชม.")
print(names2, "=", hour2, "ชม.")
print("ควรนอนเวลา:", bedtime , "นาฬิกา")
# Out:
# ชื่อกิจกรรมที่1:โซ
# ชั่วโมง:2
# ชื่อกิจกรรมที่2:บาส
# ชั่วโมง:3
# ชั่วโมงที่ต้องการนอน:8
# ตารางกิจกรรม
# โซ = 2 ชม.
# บาส = 3 ชม.
# ควรนอนเวลา: 16 นาฬิกา
